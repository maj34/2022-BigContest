# %% [markdown]
# # <font color='CC3D3D'> 0.6_4 Undersampling+SMOTE
#
# - 딥러닝 수행하기 전 불균형성을 맞추기 위해 데이터의 40%를 undersampling한 뒤 SMOTE 알고리즘을 사용해 희소 label의 양을 늘려 label 균형을 맞춰주는 데이터를 생성하는 코드
# - 불균형 해소 데이터 <span style="color:blue"> **oversample_train.csv** </span> 생성

# %% [markdown]
# # Import

# %%
# !pip install -q imblearn
print("Done!")
# Out:
# Done!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from tqdm import tqdm
import os
import pickle
import warnings
import gc

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler, SMOTE

RANDOM_STATE = 4158
pd.set_option('display.max_columns', None)
CHUNKSIZE = 50000

with open(f"{PATH}/dtypes.pkl", 'rb') as f:
    dtypes = pickle.load(f)

warnings.filterwarnings('ignore')

# %%
def loaddata(fname:str, chunksize:int, dtype:dict=None, columns:list=None):  
    df = pd.DataFrame()
    for chunk in tqdm(pd.read_csv(fname, engine='python', low_memory=True, chunksize=chunksize, dtype=dtype)):
        df = pd.concat([df, chunk], axis=0)
        del chunk
        gc.collect()

    return df

# %% [markdown]
# # Data Load

# %%
train = loaddata("../Data/master_train_data.csv", chunksize=CHUNKSIZE, dtype=dtypes)
valid = loaddata("../Data/master_public_data.csv", chunksize=CHUNKSIZE, dtype=dtypes)
# Out:
# 144it [09:18,  3.88s/it]
# 19it [01:07,  3.53s/it]

# %% [markdown]
# # Undersampling & SMOTE

# %%
_, under = train_test_split(train, test_size=0.4, shuffle=True, random_state=RANDOM_STATE, stratify=train['is_applied'])

# %%
under.shape
# Out:
# (2875603, 72)

# %%
under['is_applied'].value_counts() / under['is_applied'].value_counts().sum()
# Out:
# False    0.94544
# True     0.05456
# Name: is_applied, dtype: float64

# %%
train['is_applied'].value_counts() / train['is_applied'].value_counts().sum()
# Out:
# False    0.94544
# True     0.05456
# Name: is_applied, dtype: float64

# %%
X_under = under.drop('is_applied', axis=1)
y_under = under['is_applied']

# %%
smote = SMOTE(random_state=RANDOM_STATE, n_jobs=-1)
X_over, y_over = smote.fit_resample(X_under, y_under)

# %%
X_over.shape
# Out:
# (5437418, 71)

# %%
y_over.value_counts()
# Out:
# False    2718709
# True     2718709
# Name: is_applied, dtype: int64

# %%
master_train_oversample = pd.concat([X_over, y_over], axis=1)

# %%
master_train_oversample.head()
# Out:
#    loan_limit  loan_rate  credit_score  yearly_income  income_type  \
# 0    14000000   9.000000           710       28000000            0
# 1     9000000   6.601562           580       36000000            1
# 2     1000000  12.500000           780       25000000            0
# 3    40000000   7.898438           990       40000000            5
# 4     6000000  15.796875           910       24000000            0
#
#    employment_type  houseown_type  desired_amount  purpose  \
# 0                3              3        40000000        7
# 1                3              3         3000000        7
# 2                3              3        40000000        7
# 3                3              2       270000000        3
# 4                3              2        10000000        7
#
#    personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 0                       False                                False
# 1                       False                                False
# 2                       False                                False
# 3                       False                                False
# 4                       False                                False
#
#    existing_loan_cnt  existing_loan_amt  enter_birth  gender  k_lending_rate  \
# 0                  4           67000000           29    True            1.50
# 1                  5           78000000           49   False            1.50
# 2                  3          237000000           33   False            1.25
# 3                  1           55000000           35    True            1.50
# 4                 12          111000000           40   False            1.75
#
#    us_lending_rate  btc_price  btc_variance  eth_price  eth_variance  \
# 0             1.00   39120756     -0.026001    2640599     -0.080688
# 1             0.50   50162048     -0.027496    3790690     -0.029800
# 2             0.25   48605860      0.003300    3289621      0.013397
# 3             1.00   37052276     -0.055389    2468705     -0.083191
# 4             1.00   39541500      0.057404    2493979      0.082214
#
#    lunc_price  lunc_variance   Close    Open    High     Low     Volume  \
# 0    0.000322      -0.999512  2550.0  2570.0  2592.0  2546.0  900330000
# 1   81.518517      -0.071899  2716.0  2720.0  2720.0  2702.0  665350000
# 2   87.549965       0.050507  2714.0  2736.0  2736.0  2702.0  765680000
# 3    0.000061      -0.195312  2626.0  2634.0  2644.0  2618.0  870270000
# 4    0.000127       0.234253  2670.0  2662.0  2672.0  2654.0  469800000
#
#      Change  실업자       실업률  현재가계부채CSI  가계부채전망CSI   소비심리지수  \
# 0 -0.016296   76  2.300781        102        101  94.0000
# 1  0.000100   47  1.599609        102        101  91.8125
# 2 -0.012199   65  3.099609        103        102  93.8125
# 3  0.002100   65  1.700195        103        100  92.5000
# 4  0.012001   71  2.699219        102        101  93.3125
#
#    loanapply_insert_time_rank  loan_limit_avg_sub  loan_rate_avg_sub  \
# 0                          10       -4.161290e+06          -1.806641
# 1                           1        0.000000e+00          -0.657227
# 2                           1       -8.391304e+06           1.521484
# 3                           7        1.133333e+07          -2.546875
# 4                          14       -7.500000e+06           4.148438
#
#    bank_diversity  product_diversity  missing_value_cnt  working_year  \
# 0              22                 31                  0             2
# 1               7                  7                  2             2
# 2              20                 23                  2             2
# 3              18                 21                  2            15
# 4              26                 36                  1             9
#
#    working_month  age  holiday  weekday  hour  weekday_sin  weekday_cos  \
# 0              9   31    False        4    11    -0.433838    -0.900879
# 1             13   51    False        4     4    -0.433838    -0.900879
# 2             16   35     True        6    22    -0.781738     0.623535
# 3            165   50    False        3    14     0.433838    -0.900879
# 4            100   49    False        1    18     0.781738     0.623535
#
#    hour_sin  hour_cos  foreign  event  loan_cnt  duration  visit  segment  \
# 0  0.258789 -0.965820    False     10         5       141      1        1
# 1  0.866211  0.500000     True      6         2       354      1        4
# 2 -0.500000  0.866211    False      9         3       301      1        6
# 3 -0.500000 -0.866211    False     10         5       503      1        1
# 4 -1.000000 -0.000000    False      2         0       900      1        3
#
#    product_cnt  loan_limit_mean_x  loan_rate_mean_x  loan_limit_min_x  \
# 0            4       1.668727e+07         10.851562         1000000.0
# 1            4       1.668727e+07         10.851562         1000000.0
# 2            4       1.668727e+07         10.851562         1000000.0
# 3            7       2.464846e+07         12.179688               0.0
# 4            2       1.861316e+07         13.226562               0.0
#
#    loan_rate_min_x  loan_limit_max_x  loan_rate_max_x  bank_label  \
# 0         5.898438       100000000.0        16.296875           2
# 1         5.898438       100000000.0        16.296875           2
# 2         5.898438       100000000.0        16.296875           2
# 3         4.800781       150000000.0        19.906250           2
# 4         7.199219        50000000.0        19.906250           2
#
#    loan_limit_min_y  loan_rate_min_y  loan_limit_max_y  loan_rate_max_y  \
# 0         6000000.0         9.000000        20000000.0        10.000000
# 1         2000000.0         6.500000        20000000.0        10.000000
# 2         1000000.0         5.898438       100000000.0        16.296875
# 3               0.0         4.800781       150000000.0        19.906250
# 4               0.0        13.398438        50000000.0        19.906250
#
#    loan_limit_mean_y  loan_rate_mean_y  product_label  is_applied
# 0       1.355632e+07          9.054688              1       False
# 1       1.212646e+07          6.613281              1       False
# 2       2.030726e+07         13.828125              0       False
# 3       2.418366e+07         12.664062              0       False
# 4       2.121015e+07         15.804688              0       False

# %% [markdown]
# ## Deployment

# %%
master_train_oversample.to_csv("../Data/oversample_train.csv", index=False)
