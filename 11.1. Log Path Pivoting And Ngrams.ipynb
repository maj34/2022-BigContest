# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import pickle
from IPython.display import display
import gc
import warnings
import nltk
from nltk.util import ngrams, everygrams
from nltk.probability import ConditionalProbDist, MLEProbDist

nltk.download('punkt')
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

with open("../Data/dtypes.pkl", 'rb') as f:
    dtypes = pickle.load(f)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def viewinfo(df:pd.DataFrame) -> None:
    print(df.shape)
    print()
    df.info()
    print()
    display(df.head())

# %% [markdown]
# # Pivot Table Generation

# %%
log = pd.read_csv("../Data/2022빅콘테스트_데이터분석리그_데이터분석분야_퓨처스부문_데이터셋_220908/log_data.csv", engine='c', low_memory=True, parse_dates=['timestamp', 'date_cd'])
viewinfo(log)
# Out:
# (17843993, 6)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17843993 entries, 0 to 17843992
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   user_id         int64
#  1   event           object
#  2   timestamp       datetime64[ns]
#  3   mp_os           object
#  4   mp_app_version  object
#  5   date_cd         datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 816.8+ MB
#    user_id               event           timestamp    mp_os mp_app_version  \
# 0   576409      StartLoanApply 2022-03-25 11:12:09  Android          3.8.2
# 1   576409  ViewLoanApplyIntro 2022-03-25 11:12:09  Android          3.8.2
# 2    72878        EndLoanApply 2022-03-25 11:14:44  Android          3.8.4
# 3   645317             OpenApp 2022-03-25 11:15:09      iOS          3.6.1
# 4   645317       UseLoanManage 2022-03-25 11:15:11      iOS          3.6.1
#
#      date_cd
# 0 2022-03-25
# 1 2022-03-25
# 2 2022-03-25
# 3 2022-03-25
# 4 2022-03-25

# %% [markdown]
# * Main events: ViewLoanApplyIntro & StartLoanApply / EndLoanApply / UseLoanManage / UsePrepayCalc / UseDSRCalc / GetCreditInfo

# %%
log.sort_values(by=['user_id', 'timestamp'], inplace=True)
log.head(10)
# Out:
#           user_id          event           timestamp    mp_os mp_app_version  \
# 11709372        1  GetCreditInfo 2022-05-03 14:52:28  android            464
# 11709374        1  GetCreditInfo 2022-05-03 14:52:35  android            464
# 2451691         1  UseLoanManage 2022-06-16 23:58:41  Android         3.12.1
# 2451693         1          Login 2022-06-16 23:58:41  Android         3.12.1
# 7071607         1  GetCreditInfo 2022-06-16 23:58:42  android            464
# 10428909        7  GetCreditInfo 2022-05-22 16:39:49  android            465
# 9627339         9  GetCreditInfo 2022-05-21 23:37:58  android            465
# 9627368         9  GetCreditInfo 2022-05-21 23:43:33  android            465
# 9627370         9  GetCreditInfo 2022-05-21 23:43:52  android            465
# 9505105        11        OpenApp 2022-03-24 10:53:59      iOS          3.6.1
#
#             date_cd
# 11709372 2022-05-03
# 11709374 2022-05-03
# 2451691  2022-06-16
# 2451693  2022-06-16
# 7071607  2022-06-16
# 10428909 2022-05-22
# 9627339  2022-05-21
# 9627368  2022-05-21
# 9627370  2022-05-21
# 9505105  2022-03-24

# %%
main_events = ['ViewLoanApplyIntro', 'StartLoanApply', 'UserLoanManage', 'UsePrepayCalc', 'UseDSRCalc', 'GetCreditInfo']
# log.drop(['mp_os', 'mp_app_version'], axis=1, inplace=True)

# %%
def user_separate(df:pd.DataFrame, key:str) -> list:
    app_subdfs = []
    for app in tqdm(df[key].unique()):
        subdf = df[df[key] == app]
        app_subdfs.append(subdf)
        
    return app_subdfs

# %%
def get_event(array:list) -> pd.DataFrame:
    event_log = pd.DataFrame(columns=['user_id', 'events'])
    for item in tqdm(array):
        user_id = item['user_id'].unique().item()
        main_ = []
        for date_cd in item['date_cd'].unique():
            subdf = item[item['date_cd'] == date_cd]
            if subdf[subdf['event'].isin(main_events)].empty:
                main_.append('ETC')
            else:
                main_ += list(subdf[subdf['event'].isin(main_events)]['event'].unique())
        
        event_log = event_log.append({'user_id': np.uint32(user_id), 'events': main_}, ignore_index=True)
    
    return event_log

# %%
user_arrays = user_separate(log, key='user_id')
# Out:
# 100%|██████████| 584636/584636 [2:23:41<00:00, 67.81it/s]

# %%
threshold = len(user_arrays) // 10
listA = user_arrays[:threshold]
listB = user_arrays[threshold:2*threshold]
listC = user_arrays[2*threshold:3*threshold]
listD = user_arrays[3*threshold:4*threshold]
listE = user_arrays[4*threshold:5*threshold]
listF = user_arrays[5*threshold:6*threshold]
listG = user_arrays[6*threshold:7*threshold]
listH = user_arrays[7*threshold:8*threshold]
listI = user_arrays[8*threshold:9*threshold]
listJ = user_arrays[9*threshold:]

# %%
resultA = get_event(listA)
viewinfo(resultA)
# Out:
# 100%|██████████| 58463/58463 [12:48<00:00, 76.10it/s]
# (58463, 2)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58463 entries, 0 to 58462
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  58463 non-null  object
#  1   events   58463 non-null  object
# dtypes: object(2)
# memory usage: 913.6+ KB
#   user_id                                             events
# 0       1                     [GetCreditInfo, GetCreditInfo]
# 1       7                                    [GetCreditInfo]
# 2       9                                    [GetCreditInfo]
# 3      11  [GetCreditInfo, UsePrepayCalc, StartLoanApply,...
# 4      12  [StartLoanApply, ViewLoanApplyIntro, StartLoan...

# %%
resultB = get_event(listB)
resultC = get_event(listC)
resultD = get_event(listD)
resultE = get_event(listE)
resultF = get_event(listF)
resultG = get_event(listG)
resultH = get_event(listH)
resultI = get_event(listI)
resultJ = get_event(listJ)
# Out:
# 100%|██████████| 58463/58463 [12:42<00:00, 76.72it/s]
# 100%|██████████| 58463/58463 [12:20<00:00, 78.92it/s]
# 100%|██████████| 58463/58463 [12:37<00:00, 77.16it/s]
# 100%|██████████| 58463/58463 [12:45<00:00, 76.35it/s]
# 100%|██████████| 58463/58463 [11:45<00:00, 82.90it/s]
# 100%|██████████| 58463/58463 [12:17<00:00, 79.29it/s]
# 100%|██████████| 58463/58463 [12:13<00:00, 79.74it/s]
# 100%|██████████| 58463/58463 [12:09<00:00, 80.12it/s]
# 100%|██████████| 58469/58469 [12:15<00:00, 79.54it/s]

# %%
result = pd.concat([resultA, resultB, resultC, resultD, resultE, resultF, resultG, resultH, resultI, resultJ], axis=0)
result.reset_index(drop=True, inplace=True)

# %%
viewinfo(result)
# Out:
# (584636, 2)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584636 entries, 0 to 584635
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  584636 non-null  object
#  1   events   584636 non-null  object
# dtypes: object(2)
# memory usage: 8.9+ MB
#   user_id                                             events
# 0       1                     [GetCreditInfo, GetCreditInfo]
# 1       7                                    [GetCreditInfo]
# 2       9                                    [GetCreditInfo]
# 3      11  [GetCreditInfo, UsePrepayCalc, StartLoanApply,...
# 4      12  [StartLoanApply, ViewLoanApplyIntro, StartLoan...

# %%
result.to_csv("../Data/main_events.csv", index=False)

# %% [markdown]
# # N-grams
#
# * references
#     - [N-gram 모델 구현하기 기초 | Python, NLTK](https://seanpark11.tistory.com/89?category=962465)
#     - [확률론적 언어 모형](https://datascienceschool.net/03%20machine%20learning/03.01.05%20%ED%99%95%EB%A5%A0%EB%A1%A0%EC%A0%81%20%EC%96%B8%EC%96%B4%20%EB%AA%A8%ED%98%95.html)

# %%
event_dict = {
    'SignUp': 'sign up',
    'OpenApp': 'open app',
    'Login': 'login',
    'ViewLoanApplyIntro': 'view loan apply intro',
    'StartLoanApply': 'start loan apply',
    'CompleteIDCertification': 'complete id certification',
    'EndLoanApply': 'end loan apply',
    'UseLoanManage': 'use loan manage',
    'UsePrepayCalc': 'use prepay calculator',
    'UseDSRCalc': 'use debt service ratio calculator',
    'GetCreditInfo': 'get credit information'
}

main_events = ['ViewLoanApplyIntro', 'StartLoanApply', 'UserLoanManage', 'UsePrepayCalc', 'UseDSRCalc', 'GetCreditInfo']

# %%
df = pd.read_csv("../Data/main_events.csv")
df.head()
# Out:
#    user_id                                             events
# 0        1                 ['GetCreditInfo', 'GetCreditInfo']
# 1        7                                  ['GetCreditInfo']
# 2        9                                  ['GetCreditInfo']
# 3       11  ['GetCreditInfo', 'UsePrepayCalc', 'StartLoanA...
# 4       12  ['StartLoanApply', 'ViewLoanApplyIntro', 'EndL...

# %%
type(df['events'].iloc[0])
# Out:
# str

# %%
df['events'] = df['events'].map(lambda x: x[1:-1])
df['events'] = df['events'].map(lambda x: [item[1:-1].replace("'", "") for item in x.split(', ')])

# %%
df.head()
# Out:
#    user_id                                             events
# 0        1                     [GetCreditInfo, GetCreditInfo]
# 1        7                                    [GetCreditInfo]
# 2        9                                    [GetCreditInfo]
# 3       11  [GetCreditInfo, UsePrepayCalc, StartLoanApply,...
# 4       12  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...

# %%
type(df['events'].iloc[0])
# Out:
# list

# %%
df['num_events'] = df['events'].map(lambda x: len(x))
df.head()
# Out:
#    user_id                                             events  num_events
# 0        1                     [GetCreditInfo, GetCreditInfo]           2
# 1        7                                    [GetCreditInfo]           1
# 2        9                                    [GetCreditInfo]           1
# 3       11  [GetCreditInfo, UsePrepayCalc, StartLoanApply,...          15
# 4       12  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...          46

# %%
df['num_events'].value_counts()
# Out:
# 1      143969
# 3       61223
# 4       53599
# 2       50047
# 5       32489
#         ...
# 310         1
# 231         1
# 402         1
# 240         1
# 355         1
# Name: num_events, Length: 328, dtype: int64

# %% [markdown]
# ## People with more than 3 tags

# %%
df['event_sent'] = df['events'].map(lambda x: ' '.join(x))

# %%
to_ngram = df[df['num_events'] >= 3]
no_ngram = df[df['num_events'] < 3]

# %%
print(no_ngram['num_events'].max())
print(no_ngram['num_events'].min())
# Out:
# 2
# 1

# %%
to_ngram.reset_index(drop=True, inplace=True)

# %%
to_ngram['trigrams'] = to_ngram['events'].map(lambda x: ngrams(x, n=3))
to_ngram.head(10)
# Out:
#    user_id                                             events  num_events  \
# 0       11  [GetCreditInfo, UsePrepayCalc, StartLoanApply,...          15
# 1       12  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...          46
# 2       17  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...           7
# 3       19  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...           3
# 4       20  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...          25
# 5       21  [ETC, GetCreditInfo, GetCreditInfo, StartLoanA...           8
# 6       24  [GetCreditInfo, StartLoanApply, ViewLoanApplyI...           5
# 7       25  [GetCreditInfo, StartLoanApply, ViewLoanApplyI...          13
# 8       26  [ETC, ETC, ViewLoanApplyIntro, StartLoanApply,...           7
# 9       27  [GetCreditInfo, GetCreditInfo, GetCreditInfo, ...          35
#
#                                           event_sent  \
# 0  GetCreditInfo UsePrepayCalc StartLoanApply Vie...
# 1  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 2  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 4  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 5  ETC GetCreditInfo GetCreditInfo StartLoanApply...
# 6  GetCreditInfo StartLoanApply ViewLoanApplyIntr...
# 7  GetCreditInfo StartLoanApply ViewLoanApplyIntr...
# 8  ETC ETC ViewLoanApplyIntro StartLoanApply View...
# 9  GetCreditInfo GetCreditInfo GetCreditInfo GetC...
#
#                          trigrams
# 0  <zip object at 0x7f741d105b90>
# 1  <zip object at 0x7f741d105a50>
# 2  <zip object at 0x7f741d105820>
# 3  <zip object at 0x7f741d105550>
# 4  <zip object at 0x7f741d105370>
# 5  <zip object at 0x7f741d1050a0>
# 6  <zip object at 0x7f741d172eb0>
# 7  <zip object at 0x7f741d172d20>
# 8  <zip object at 0x7f741d172a50>
# 9  <zip object at 0x7f741d172640>

# %%
to_ngram['trigrams_list'] = to_ngram['events'].map(lambda x: list(ngrams(x, n=3)))
to_ngram.head(10)
# Out:
#    user_id                                             events  num_events  \
# 0       11  [GetCreditInfo, UsePrepayCalc, StartLoanApply,...          15
# 1       12  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...          46
# 2       17  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...           7
# 3       19  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...           3
# 4       20  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...          25
# 5       21  [ETC, GetCreditInfo, GetCreditInfo, StartLoanA...           8
# 6       24  [GetCreditInfo, StartLoanApply, ViewLoanApplyI...           5
# 7       25  [GetCreditInfo, StartLoanApply, ViewLoanApplyI...          13
# 8       26  [ETC, ETC, ViewLoanApplyIntro, StartLoanApply,...           7
# 9       27  [GetCreditInfo, GetCreditInfo, GetCreditInfo, ...          35
#
#                                           event_sent  \
# 0  GetCreditInfo UsePrepayCalc StartLoanApply Vie...
# 1  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 2  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 4  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 5  ETC GetCreditInfo GetCreditInfo StartLoanApply...
# 6  GetCreditInfo StartLoanApply ViewLoanApplyIntr...
# 7  GetCreditInfo StartLoanApply ViewLoanApplyIntr...
# 8  ETC ETC ViewLoanApplyIntro StartLoanApply View...
# 9  GetCreditInfo GetCreditInfo GetCreditInfo GetC...
#
#                          trigrams  \
# 0  <zip object at 0x7f741d105b90>
# 1  <zip object at 0x7f741d105a50>
# 2  <zip object at 0x7f741d105820>
# 3  <zip object at 0x7f741d105550>
# 4  <zip object at 0x7f741d105370>
# 5  <zip object at 0x7f741d1050a0>
# 6  <zip object at 0x7f741d172eb0>
# 7  <zip object at 0x7f741d172d20>
# 8  <zip object at 0x7f741d172a50>
# 9  <zip object at 0x7f741d172640>
#
#                                        trigrams_list
# 0  [(GetCreditInfo, UsePrepayCalc, StartLoanApply...
# 1  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 2  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 3  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 4  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 5  [(ETC, GetCreditInfo, GetCreditInfo), (GetCred...
# 6  [(GetCreditInfo, StartLoanApply, ViewLoanApply...
# 7  [(GetCreditInfo, StartLoanApply, ViewLoanApply...
# 8  [(ETC, ETC, ViewLoanApplyIntro), (ETC, ViewLoa...
# 9  [(GetCreditInfo, GetCreditInfo, GetCreditInfo)...

# %%
to_ngram['dist'] = to_ngram['trigrams'].map(lambda x: nltk.ConditionalFreqDist([((t[0], t[1]), t[2]) for t in x]))
to_ngram
# Out:
#         user_id                                             events  \
# 0            11  [GetCreditInfo, UsePrepayCalc, StartLoanApply,...
# 1            12  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 2            17  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 3            19  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 4            20  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# ...         ...                                                ...
# 390615   879692  [GetCreditInfo, StartLoanApply, ViewLoanApplyI...
# 390616   879693  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 390617   879694  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 390618   879695  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 390619   879696  [GetCreditInfo, ViewLoanApplyIntro, EndLoanApply]
#
#         num_events                                         event_sent  \
# 0               15  GetCreditInfo UsePrepayCalc StartLoanApply Vie...
# 1               46  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 2                7  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 3                3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 4               25  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# ...            ...                                                ...
# 390615          16  GetCreditInfo StartLoanApply ViewLoanApplyIntr...
# 390616          19  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 390617           3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 390618           3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 390619           3      GetCreditInfo ViewLoanApplyIntro EndLoanApply
#
#                               trigrams  \
# 0       <zip object at 0x7f741d105b90>
# 1       <zip object at 0x7f741d105a50>
# 2       <zip object at 0x7f741d105820>
# 3       <zip object at 0x7f741d105550>
# 4       <zip object at 0x7f741d105370>
# ...                                ...
# 390615  <zip object at 0x7f72a2bdc4b0>
# 390616  <zip object at 0x7f72a2bdc690>
# 390617  <zip object at 0x7f72a2bdc870>
# 390618  <zip object at 0x7f72a2bdca50>
# 390619  <zip object at 0x7f72a2bdcc30>
#
#                                             trigrams_list  \
# 0       [(GetCreditInfo, UsePrepayCalc, StartLoanApply...
# 1       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 2       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 3       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 4       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# ...                                                   ...
# 390615  [(GetCreditInfo, StartLoanApply, ViewLoanApply...
# 390616  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 390617  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 390618  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 390619  [(GetCreditInfo, ViewLoanApplyIntro, EndLoanAp...
#
#                                                      dist
# 0       {('GetCreditInfo', 'UsePrepayCalc'): {'StartLo...
# 1       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 2       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 3       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 4       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# ...                                                   ...
# 390615  {('GetCreditInfo', 'StartLoanApply'): {'ViewLo...
# 390616  {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 390617  {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 390618  {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 390619  {('GetCreditInfo', 'ViewLoanApplyIntro'): {'En...
#
# [390620 rows x 7 columns]

# %%
to_ngram['prob'] = to_ngram['dist'].map(lambda x: ConditionalProbDist(x, MLEProbDist))
to_ngram
# Out:
#         user_id                                             events  \
# 0            11  [GetCreditInfo, UsePrepayCalc, StartLoanApply,...
# 1            12  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 2            17  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 3            19  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 4            20  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# ...         ...                                                ...
# 390615   879692  [GetCreditInfo, StartLoanApply, ViewLoanApplyI...
# 390616   879693  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 390617   879694  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 390618   879695  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 390619   879696  [GetCreditInfo, ViewLoanApplyIntro, EndLoanApply]
#
#         num_events                                         event_sent  \
# 0               15  GetCreditInfo UsePrepayCalc StartLoanApply Vie...
# 1               46  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 2                7  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 3                3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 4               25  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# ...            ...                                                ...
# 390615          16  GetCreditInfo StartLoanApply ViewLoanApplyIntr...
# 390616          19  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 390617           3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 390618           3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 390619           3      GetCreditInfo ViewLoanApplyIntro EndLoanApply
#
#                               trigrams  \
# 0       <zip object at 0x7f741d105b90>
# 1       <zip object at 0x7f741d105a50>
# 2       <zip object at 0x7f741d105820>
# 3       <zip object at 0x7f741d105550>
# 4       <zip object at 0x7f741d105370>
# ...                                ...
# 390615  <zip object at 0x7f72a2bdc4b0>
# 390616  <zip object at 0x7f72a2bdc690>
# 390617  <zip object at 0x7f72a2bdc870>
# 390618  <zip object at 0x7f72a2bdca50>
# 390619  <zip object at 0x7f72a2bdcc30>
#
#                                             trigrams_list  \
# 0       [(GetCreditInfo, UsePrepayCalc, StartLoanApply...
# 1       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 2       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 3       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 4       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# ...                                                   ...
# 390615  [(GetCreditInfo, StartLoanApply, ViewLoanApply...
# 390616  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 390617  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 390618  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 390619  [(GetCreditInfo, ViewLoanApplyIntro, EndLoanAp...
#
#                                                      dist  \
# 0       {('GetCreditInfo', 'UsePrepayCalc'): {'StartLo...
# 1       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 2       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 3       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 4       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# ...                                                   ...
# 390615  {('GetCreditInfo', 'StartLoanApply'): {'ViewLo...
# 390616  {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 390617  {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 390618  {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 390619  {('GetCreditInfo', 'ViewLoanApplyIntro'): {'En...
#
#                                                      prob
# 0       {('GetCreditInfo', 'UsePrepayCalc'): <MLEProbD...
# 1       {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...
# 2       {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...
# 3       {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...
# 4       {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...
# ...                                                   ...
# 390615  {('GetCreditInfo', 'StartLoanApply'): <MLEProb...
# 390616  {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...
# 390617  {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...
# 390618  {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...
# 390619  {('GetCreditInfo', 'ViewLoanApplyIntro'): <MLE...
#
# [390620 rows x 8 columns]

# %%
i = 0
dist = to_ngram['dist'].iloc[i]
last_prev, last = to_ngram['events'].iloc[0][-2:]

cpd = ConditionalProbDist(dist, MLEProbDist)
print(cpd)
print(cpd[(last_prev, last)])

for item in main_events:
    print(f"Prob of {item} given {last_prev, last} -> {cpd[(last_prev, last)].prob(item)}")
# Out:
# <ConditionalProbDist with 8 conditions>
# <MLEProbDist based on 3 samples>
# Prob of ViewLoanApplyIntro given ('ViewLoanApplyIntro', 'EndLoanApply') -> 0.0
# Prob of StartLoanApply given ('ViewLoanApplyIntro', 'EndLoanApply') -> 0.6666666666666666
# Prob of UserLoanManage given ('ViewLoanApplyIntro', 'EndLoanApply') -> 0.0
# Prob of UsePrepayCalc given ('ViewLoanApplyIntro', 'EndLoanApply') -> 0.0
# Prob of UseDSRCalc given ('ViewLoanApplyIntro', 'EndLoanApply') -> 0.0
# Prob of GetCreditInfo given ('ViewLoanApplyIntro', 'EndLoanApply') -> 0.3333333333333333

# %%
maximal_action = []
minimal_action = []
for i in tqdm(range(to_ngram.shape[0])):
    dist = to_ngram['dist'].iloc[i]
    last_prev, last = to_ngram['events'].iloc[i][-2:]

    cpd = to_ngram['prob'].iloc[i]
    scores = np.array([cpd[(last_prev, last)].prob(item) for item in main_events])

    max_idx = np.where(scores == scores.max())[0]
    max_item = np.random.choice(np.array(main_events)[max_idx])

    try:
        min_idx = np.where((scores == scores.min()) & (scores > 0))[0]
        min_item = np.random.choice(np.array(main_events)[min_idx])
    except:
        min_idx = np.where((scores == scores.min()))[0]
        min_item = np.random.choice(np.array(main_events)[min_idx])        

    maximal_action.append(max_item)
    minimal_action.append(min_item)
    
to_ngram['maximal_action'] = maximal_action
to_ngram['minimal_action'] = minimal_action
# Out:
# 100%|██████████| 390620/390620 [01:04<00:00, 6014.14it/s]

# %%
to_ngram
# Out:
#         user_id                                             events  \
# 0            11  [GetCreditInfo, UsePrepayCalc, StartLoanApply,...
# 1            12  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 2            17  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 3            19  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 4            20  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# ...         ...                                                ...
# 390615   879692  [GetCreditInfo, StartLoanApply, ViewLoanApplyI...
# 390616   879693  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 390617   879694  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 390618   879695  [StartLoanApply, ViewLoanApplyIntro, EndLoanAp...
# 390619   879696  [GetCreditInfo, ViewLoanApplyIntro, EndLoanApply]
#
#         num_events                                         event_sent  \
# 0               15  GetCreditInfo UsePrepayCalc StartLoanApply Vie...
# 1               46  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 2                7  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 3                3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 4               25  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# ...            ...                                                ...
# 390615          16  GetCreditInfo StartLoanApply ViewLoanApplyIntr...
# 390616          19  StartLoanApply ViewLoanApplyIntro EndLoanApply...
# 390617           3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 390618           3     StartLoanApply ViewLoanApplyIntro EndLoanApply
# 390619           3      GetCreditInfo ViewLoanApplyIntro EndLoanApply
#
#                               trigrams  \
# 0       <zip object at 0x7f741d105b90>
# 1       <zip object at 0x7f741d105a50>
# 2       <zip object at 0x7f741d105820>
# 3       <zip object at 0x7f741d105550>
# 4       <zip object at 0x7f741d105370>
# ...                                ...
# 390615  <zip object at 0x7f72a2bdc4b0>
# 390616  <zip object at 0x7f72a2bdc690>
# 390617  <zip object at 0x7f72a2bdc870>
# 390618  <zip object at 0x7f72a2bdca50>
# 390619  <zip object at 0x7f72a2bdcc30>
#
#                                             trigrams_list  \
# 0       [(GetCreditInfo, UsePrepayCalc, StartLoanApply...
# 1       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 2       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 3       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 4       [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# ...                                                   ...
# 390615  [(GetCreditInfo, StartLoanApply, ViewLoanApply...
# 390616  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 390617  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 390618  [(StartLoanApply, ViewLoanApplyIntro, EndLoanA...
# 390619  [(GetCreditInfo, ViewLoanApplyIntro, EndLoanAp...
#
#                                                      dist  \
# 0       {('GetCreditInfo', 'UsePrepayCalc'): {'StartLo...
# 1       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 2       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 3       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 4       {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# ...                                                   ...
# 390615  {('GetCreditInfo', 'StartLoanApply'): {'ViewLo...
# 390616  {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 390617  {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 390618  {('StartLoanApply', 'ViewLoanApplyIntro'): {'E...
# 390619  {('GetCreditInfo', 'ViewLoanApplyIntro'): {'En...
#
#                                                      prob  maximal_action  \
# 0       {('GetCreditInfo', 'UsePrepayCalc'): <MLEProbD...  StartLoanApply
# 1       {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...  StartLoanApply
# 2       {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...   GetCreditInfo
# 3       {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...   GetCreditInfo
# 4       {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...  StartLoanApply
# ...                                                   ...             ...
# 390615  {('GetCreditInfo', 'StartLoanApply'): <MLEProb...   UsePrepayCalc
# 390616  {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...   UsePrepayCalc
# 390617  {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...  UserLoanManage
# 390618  {('StartLoanApply', 'ViewLoanApplyIntro'): <ML...      UseDSRCalc
# 390619  {('GetCreditInfo', 'ViewLoanApplyIntro'): <MLE...      UseDSRCalc
#
#             minimal_action
# 0       ViewLoanApplyIntro
# 1           UserLoanManage
# 2       ViewLoanApplyIntro
# 3               UseDSRCalc
# 4       ViewLoanApplyIntro
# ...                    ...
# 390615       GetCreditInfo
# 390616       GetCreditInfo
# 390617       UsePrepayCalc
# 390618          UseDSRCalc
# 390619  ViewLoanApplyIntro
#
# [390620 rows x 10 columns]

# %%
to_ngram['maximal_action'].value_counts()
# Out:
# GetCreditInfo         113675
# StartLoanApply         96258
# ViewLoanApplyIntro     52329
# UsePrepayCalc          42829
# UserLoanManage         42812
# UseDSRCalc             42717
# Name: maximal_action, dtype: int64

# %%
to_ngram['minimal_action'].value_counts()
# Out:
# UserLoanManage        73086
# UsePrepayCalc         72983
# UseDSRCalc            72864
# ViewLoanApplyIntro    66554
# StartLoanApply        54347
# GetCreditInfo         50786
# Name: minimal_action, dtype: int64

# %%
to_ngram.to_csv("../Data/ngram_.csv", index=False)

# %%
Datano_ngram.to_csv("../Data/no_ngram_.csv", index=False)
